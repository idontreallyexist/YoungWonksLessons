# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForCausalLM
import torch

# %%
tokenizergpt = AutoTokenizer.from_pretrained("distilbert/distilgpt2")
gpt = AutoModelForCausalLM.from_pretrained("distilbert/distilgpt2")
tokenizerflan = AutoTokenizer.from_pretrained("google/flan-t5-base")
flan = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
tokenizerblender = AutoTokenizer.from_pretrained("facebook/blenderbot-400M-distill")
blenderbot = AutoModelForSeq2SeqLM.from_pretrained("facebook/blenderbot-400M-distill")

# %%
def generate_text(text,model,tokenizer):
    input = tokenizer.encode(text, return_tensors="pt")
    output = model.generate(input, max_length=100, do_sample=True, pad_token_id=tokenizer.eos_token_id)
    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
print(generate_text("Explain how artificial intelligence helps in healthcare.",gpt,tokenizergpt))
print(generate_text("Explain how artificial intelligence helps in healthcare.",flan,tokenizerflan))
print(generate_text("Explain how artificial intelligence helps in healthcare.",blenderbot,tokenizerblender))
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Explain how artificial intelligence helps in healthcare.
# Artificial Intelligence (AI) has been in use in healthcare.
#  I'm not sure, but I do know that it has been shown to reduce the risk of certain chronic diseases.

# %%
print(generate_text("Write the first paragraph of a mystery story set in space.",gpt,tokenizergpt))
print(generate_text('Write the first paragraph of a mystery story set in space.',flan,tokenizerflan))
print(generate_text("Write the first paragraph of a mystery story set in space.",blenderbot,tokenizerblender))
# Out:
# Write the first paragraph of a mystery story set in space.
# There is a lion, which is already on his lap. The lion's human body begins to turn, but it can't save itself.
#  I would love to be able to write a story like that. How long did it take you to write it?

# %%
print(generate_text("What’s your favorite movie and why?",gpt,tokenizergpt))
print(generate_text('What’s your favorite movie and why?',flan,tokenizerflan))
print(generate_text("What’s your favorite movie and why?",blenderbot,tokenizerblender))
# Out:
# What’s your favorite movie and why?
#
#
#
#
#
#
# ’s the worst-of-three year period in which our films have been cancelled. This isn't just about the last 12 months, but also the year since the last big screen movie ended. From there, we will release six more top-grossing films on Nov. 9, 2016 (and an eighth of those movies were cancelled, with another 1 percent of those made for the week).
# The
# tyrol
#  I don't really have a favorite movie. I just like movies that make me feel nostalgic.
