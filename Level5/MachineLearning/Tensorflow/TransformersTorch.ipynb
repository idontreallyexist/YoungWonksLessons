# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForCausalLM
import torch

# %%
tokenizergpt = AutoTokenizer.from_pretrained("distilbert/distilgpt2")
gpt = AutoModelForCausalLM.from_pretrained("distilbert/distilgpt2")
tokenizerflan = AutoTokenizer.from_pretrained("google/flan-t5-base")
flan = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
tokenizerblender = AutoTokenizer.from_pretrained("facebook/blenderbot-400M-distill")
blenderbot = AutoModelForSeq2SeqLM.from_pretrained("facebook/blenderbot-400M-distill")

# %%
def generate_text(text,model,tokenizer):
    input = tokenizer.encode(text, return_tensors="pt")
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    output = model.generate(input, do_sample=True, pad_token_id=tokenizer.pad_token_id, max_new_tokens=200)
    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
print("gpt: "+generate_text("Explain how artificial intelligence helps in healthcare.",gpt,tokenizergpt))
print("flan: "+generate_text("Explain how artificial intelligence helps in healthcare.",flan,tokenizerflan))
print("blender: "+generate_text("Explain how artificial intelligence helps in healthcare.",blenderbot,tokenizerblender))
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# gpt: Explain how artificial intelligence helps in healthcare.
#
#
#
#
#
# Follow us on facebook - or subscribe to the RSS feed - you can help us keep our journalism powered by Disqus.
# flan: In 2014, a company called iRealm made a device which enables automated medical records to be kept online so that the right patient is being seen and treated.
# blender:  I'm not sure, but I do know that it can help reduce the risk of some types of chronic disease.

# %%
print("gpt: "+generate_text("Write the first paragraph of a mystery story set in space.",gpt,tokenizergpt))
print("flan: "+generate_text('Write the first paragraph of a mystery story set in space.',flan,tokenizerflan))
print("blender: "+generate_text("Write the first paragraph of a mystery story set in space.",blenderbot,tokenizerblender))
# Out:
# gpt: Write the first paragraph of a mystery story set in space. Or a story set in space. Or a story set in space. How the reader can figure out which story is going to be right in front of them. The mystery story will only be solved if the story has all the pieces together to get the story off the ground. We will never know.
# flan: When someone leaves a space station, they come across a small spaceship flying over it.
# blender:  I would love to do that one day! Do you have any ideas as to what it would be about?

# %%
print("gpt: "+generate_text("What’s your favorite movie and why?",gpt,tokenizergpt))
print("flan: "+generate_text('What’s your favorite movie and why?',flan,tokenizerflan))
print("blender: "+generate_text("What’s your favorite movie and why?",blenderbot,tokenizerblender))
# Out:
# gpt: What’s your favorite movie and why?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# flan: anatomy of teen hunger the first death of innocence , when mr. richard williams was playing the role of the father of the tiger
# blender:  I don't really have a favorite movie, but I do like musicals a lot.
